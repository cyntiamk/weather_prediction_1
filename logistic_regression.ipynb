# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv('kyoto_weather.csv')
weather
# Out:
#                       Date  Temperature(C)  Max_temp  Min_temp  Dew_point  \
# 0      2017-01-01 00:00:00               6         7         4        3.6
# 1      2017-01-01 01:00:00               7         9         5        4.6
# 2      2017-01-01 02:00:00               9        10         7        2.0
# 3      2017-01-01 03:00:00              11        11        10        0.2
# 4      2017-01-01 04:00:00              12        12        11        0.6
# 5      2017-01-01 05:00:00              12        12        12        0.0
# 6      2017-01-01 06:00:00              12        13        12       -0.6
# 7      2017-01-01 07:00:00              12        13        12        6.8
# 8      2017-01-01 08:00:00              12        12        12        9.4
# 9      2017-01-01 09:00:00              10        11        10       -1.4
# 10     2017-01-01 10:00:00               9         9         9        6.4
# 11     2017-01-01 11:00:00               8         8         8        0.2
# 12     2017-01-01 12:00:00               8         9         7        1.0
# 13     2017-01-01 13:00:00               9         9         9        5.2
# 14     2017-01-01 14:00:00               0         0         0       -1.8
# 15     2017-01-01 15:00:00               0         0         0       -1.8
# 16     2017-01-01 16:00:00               0         0         0       -1.8
# 17     2017-01-01 17:00:00              -2        -2        -2       -4.6
# 18     2017-01-01 18:00:00              -2        -2        -2       -4.6
# 19     2017-01-01 19:00:00              -2        -2        -2       -4.6
# 20     2017-01-01 20:00:00              -3        -3        -3       -5.6
# 21     2017-01-01 21:00:00               2         2         2       -0.6
# 22     2017-01-01 22:00:00               2         2         2        0.6
# 23     2017-01-01 23:00:00               3         5         1        1.2
# 24     2017-01-02 00:00:00               4         6         2        2.6
# 25     2017-01-02 01:00:00               7         8         5        2.0
# 26     2017-01-02 02:00:00               9         9         8        2.0
# 27     2017-01-02 03:00:00               9        10         9        0.4
# 28     2017-01-02 04:00:00              10        11        10        1.4
# 29     2017-01-02 05:00:00              11        12        11        1.8
# ...                    ...             ...       ...       ...        ...
# 17413  2018-12-29 19:00:00              -5        -5        -5       -7.6
# 17414  2018-12-29 20:00:00              -5        -5        -5       -6.8
# 17415  2018-12-29 21:00:00               0         0         0       -1.8
# 17416  2018-12-29 22:00:00               0         0         0       -1.8
# 17417  2018-12-29 23:00:00               1         2         0       -0.4
# 17418  2018-12-30 00:00:00               2         3         1       -0.8
# 17419  2018-12-30 01:00:00               4         4         3       -1.2
# 17420  2018-12-30 02:00:00               5         6         5       -3.0
# 17421  2018-12-30 03:00:00               7         7         7       -2.6
# 17422  2018-12-30 04:00:00               7         7         7       -1.8
# 17423  2018-12-30 05:00:00               8         8         7       -2.2
# 17424  2018-12-30 06:00:00               8         8         8       -2.2
# 17425  2018-12-30 07:00:00               7         8         7       -2.6
# 17426  2018-12-30 08:00:00               6         7         6       -2.8
# 17427  2018-12-30 09:00:00               5         5         5       -3.0
# 17428  2018-12-30 10:00:00               4         4         4       -3.2
# 17429  2018-12-30 11:00:00               4         4         3       -2.2
# 17430  2018-12-30 12:00:00               4         4         3       -2.2
# 17431  2018-12-30 13:00:00               4         4         4       -5.0
# 17432  2018-12-30 14:00:00              -3        -3        -3       -5.2
# 17433  2018-12-30 15:00:00              -3        -3        -3       -5.2
# 17434  2018-12-30 16:00:00              -3        -3        -3       -5.2
# 17435  2018-12-30 17:00:00              -4        -4        -4       -6.6
# 17436  2018-12-30 18:00:00              -4        -4        -4       -6.6
# 17437  2018-12-30 19:00:00              -4        -4        -4       -6.6
# 17438  2018-12-30 20:00:00              -3        -3        -3       -5.6
# 17439  2018-12-30 21:00:00               1         1         1       -1.8
# 17440  2018-12-30 22:00:00               2         2         2       -0.6
# 17441  2018-12-30 23:00:00               3         4         2       -0.2
# 17442  2018-12-31 00:00:00               3         4         2       -0.2
#
#        Max_dew_point  Min_dew_point  Pressure  Humidity  Wind  Clouds  \
# 0                4.6            1.6      1028        88     2      75
# 1                6.6            2.6      1028        88     1      75
# 2                3.0            0.0      1028        65     1      40
# 3                0.2           -0.8      1027        46     1      20
# 4                0.6           -0.4      1026        43     1      20
# 5                0.0            0.0      1026        40     2      20
# 6                0.4           -0.6      1025        37     2      20
# 7                7.8            6.8      1025        74     2      20
# 8                9.4            9.4      1025        87     2      20
# 9               -0.4           -1.4      1025        43     1      40
# 10               6.4            6.4      1026        87     1      20
# 11               0.2            0.2      1026        61     0      20
# 12               2.0            0.0      1025        65     1      20
# 13               5.2            5.2      1025        81     2       0
# 14              -1.8           -1.8      1017        91     1       8
# 15              -1.8           -1.8      1016        91     1       0
# 16              -1.8           -1.8      1016        91     1       0
# 17              -4.6           -4.6      1015        87     1      24
# 18              -4.6           -4.6      1015        87     1      24
# 19              -4.6           -4.6      1015        87     1      24
# 20              -5.6           -5.6      1014        87     1       0
# 21              -0.6           -0.6      1022        87     1      75
# 22               0.6            0.6      1022        93     1      40
# 23               3.2           -0.8      1022        91     0      20
# 24               4.6            0.6      1022        93     2      20
# 25               3.0            0.0      1022        75     1      20
# 26               2.0            1.0      1022        65     1      75
# 27               1.4            0.4      1021        57     1      75
# 28               2.4            1.4      1020        57     1      75
# 29               2.8            1.8      1019        54     1      75
# ...              ...            ...       ...       ...   ...     ...
# 17413           -7.6           -7.6      1016        87     2       0
# 17414           -6.8           -6.8      1017        91     1      12
# 17415           -1.8           -1.8      1025        91     1      20
# 17416           -1.8           -1.8      1026        91     1      20
# 17417            0.6           -1.4      1027        93     2      20
# 17418            0.2           -1.8      1027        86     4      20
# 17419           -1.2           -2.2      1027        74     3      20
# 17420           -2.0           -3.0      1027        60     4      20
# 17421           -2.6           -2.6      1027        52     7      20
# 17422           -1.8           -1.8      1026        56     8      40
# 17423           -2.2           -3.2      1026        49     7      40
# 17424           -2.2           -2.2      1026        49     9      40
# 17425           -1.6           -2.6      1028        52     8      20
# 17426           -1.8           -2.8      1028        56     6      40
# 17427           -3.0           -3.0      1029        60     5      20
# 17428           -3.2           -3.2      1030        64     4      20
# 17429           -2.2           -3.2      1030        69     3      40
# 17430           -2.2           -3.2      1031        69     1      40
# 17431           -5.0           -5.0      1031        55     5      40
# 17432           -5.2           -5.2      1022        89     2       0
# 17433           -5.2           -5.2      1022        89     2       0
# 17434           -5.2           -5.2      1022        89     2       0
# 17435           -6.6           -6.6      1022        87     2      24
# 17436           -6.6           -6.6      1022        87     2      24
# 17437           -6.6           -6.6      1022        87     2      24
# 17438           -5.6           -5.6      1022        87     1      64
# 17439           -1.8           -1.8      1032        86     2      75
# 17440           -0.6           -0.6      1032        87     2      75
# 17441            0.8           -1.2      1032        84     3      75
# 17442            0.8           -1.2      1033        84     2      75
#
#       Description
# 0          Clouds
# 1          Clouds
# 2          Clouds
# 3          Clouds
# 4          Clouds
# 5          Clouds
# 6          Clouds
# 7          Clouds
# 8          Clouds
# 9          Clouds
# 10         Clouds
# 11         Clouds
# 12         Clouds
# 13          Clear
# 14          Clear
# 15          Clear
# 16          Clear
# 17         Clouds
# 18         Clouds
# 19         Clouds
# 20          Clear
# 21         Clouds
# 22         Clouds
# 23         Clouds
# 24         Clouds
# 25         Clouds
# 26         Clouds
# 27         Clouds
# 28         Clouds
# 29         Clouds
# ...           ...
# 17413       Clear
# 17414      Clouds
# 17415      Clouds
# 17416      Clouds
# 17417      Clouds
# 17418      Clouds
# 17419      Clouds
# 17420      Clouds
# 17421      Clouds
# 17422      Clouds
# 17423      Clouds
# 17424      Clouds
# 17425        Rain
# 17426      Clouds
# 17427      Clouds
# 17428      Clouds
# 17429      Clouds
# 17430      Clouds
# 17431      Clouds
# 17432       Clear
# 17433       Clear
# 17434       Clear
# 17435      Clouds
# 17436      Clouds
# 17437      Clouds
# 17438      Clouds
# 17439      Clouds
# 17440      Clouds
# 17441      Clouds
# 17442      Clouds
#
# [17443 rows x 12 columns]

# %%
# Assign X (data) and y (target)
predictors = ['Temperature(C)','Dew_point','Pressure','Wind','Clouds']
X = weather[predictors]
y = weather["Description"]
print(X.shape, y.shape)
# Out:
# (17443, 5) (17443,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.8334352545482342
# Testing Data Score: 0.8346709470304976

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['Clouds' 'Clear' 'Clouds' 'Clear' 'Clouds' 'Rain' 'Clouds' 'Clouds'
#  'Clouds' 'Clouds']
# First 10 Actual labels: ['Rain', 'Clear', 'Clouds', 'Clear', 'Clouds', 'Clouds', 'Clouds', 'Clouds', 'Rain', 'Clouds']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True).head()
# Out:
#   Prediction  Actual
# 0     Clouds    Rain
# 1      Clear   Clear
# 2     Clouds  Clouds
# 3      Clear   Clear
# 4     Clouds  Clouds
