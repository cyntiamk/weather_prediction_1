# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os

# %%
weather = pd.read_csv('kyoto_weather.csv')
weather.head()
# Out:
#                   Date  Temperature(C)  Max_temp  Min_temp  Dew_point  \
# 0  2017-01-01 00:00:00               6         7         4        3.6
# 1  2017-01-01 01:00:00               7         9         5        4.6
# 2  2017-01-01 02:00:00               9        10         7        2.0
# 3  2017-01-01 03:00:00              11        11        10        0.2
# 4  2017-01-01 04:00:00              12        12        11        0.6
#
#    Max_dew_point  Min_dew_point  Pressure  Humidity  Wind  Clouds Description
# 0            4.6            1.6      1028        88     2      75      Clouds
# 1            6.6            2.6      1028        88     1      75      Clouds
# 2            3.0            0.0      1028        65     1      40      Clouds
# 3            0.2           -0.8      1027        46     1      20      Clouds
# 4            0.6           -0.4      1026        43     1      20      Clouds

# %%
# Assign X (data) and y (target)
predictors = ['Temperature(C)','Dew_point','Pressure','Wind','Clouds']
X = weather[predictors]
y = weather["Description"]

# %%
# Split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create the SVC Model
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Fit the model using the grid search estimator. 
# This will take the SVC model and try each combination of parameters
grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] C=1, gamma=0.0001 ...............................................
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/model_selection/_split.py:605: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# [CV] ...... C=1, gamma=0.0001, score=0.8306211322484529, total=   3.4s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.7s remaining:    0.0s
# [CV] ....... C=1, gamma=0.0001, score=0.832416322787712, total=   3.4s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    7.4s remaining:    0.0s
# [CV] ...... C=1, gamma=0.0001, score=0.8338306173972917, total=   3.3s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.8306211322484529, total=   3.3s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ........ C=1, gamma=0.001, score=0.832416322787712, total=   3.4s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.8338306173972917, total=   3.2s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.8306211322484529, total=   3.5s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ......... C=1, gamma=0.01, score=0.832416322787712, total=   3.4s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.8338306173972917, total=   3.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.8294751317900527, total=   3.9s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.8333333333333334, total=   3.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ...... C=5, gamma=0.0001, score=0.8347486802845995, total=   3.7s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.8294751317900527, total=   3.8s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.8333333333333334, total=   3.3s
# [CV] C=5, gamma=0.001 ................................................
# [CV] ....... C=5, gamma=0.001, score=0.8347486802845995, total=   3.8s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.8294751317900527, total=   3.9s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.8333333333333334, total=   3.4s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ........ C=5, gamma=0.01, score=0.8347486802845995, total=   3.8s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.8287875315150126, total=   3.9s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.8340210912425493, total=   3.8s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] ..... C=10, gamma=0.0001, score=0.8358962588937342, total=   3.8s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.8287875315150126, total=   3.9s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.8340210912425493, total=   3.8s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.8358962588937342, total=   4.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.8287875315150126, total=   4.1s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.8340210912425493, total=   4.2s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.8358962588937342, total=   4.1s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  1.8min finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
# List the best parameters for this dataset
print(grid.best_params_)
# Out:
# {'C': 10, 'gamma': 0.0001}

# %%
# List the best score
print(grid.best_score_)
# Out:
# 0.8329001681700046

# %%
# Make predictions with the hypertuned model
predictions = grid.predict(X_test)

print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['Clouds' 'Clear' 'Clear' 'Clouds' 'Clouds' 'Clouds' 'Clouds' 'Clear'
#  'Clouds' 'Clouds']
# First 10 Actual labels: ['Clouds', 'Clear', 'Clear', 'Clouds', 'Clouds', 'Clouds', 'Clouds', 'Clear', 'Clouds', 'Clouds']

# %%
# Calculate classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions,
                            target_names=predictors))
# Out:
#                 precision    recall  f1-score   support
#
# Temperature(C)       0.99      1.00      0.99       758
#      Dew_point       0.81      0.93      0.86      2598
#       Pressure       0.00      0.00      0.00         1
#           Wind       0.00      0.00      0.00         1
#         Clouds       0.00      0.00      0.00        20
#
#    avg / total       0.80      0.82      0.80      4361
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/metrics/classification.py:1428: UserWarning: labels size, 8, does not match size of target_names, 5
#   .format(len(labels), len(target_names))
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#      Prediction  Actual
# 0        Clouds  Clouds
# 1         Clear   Clear
# 2         Clear   Clear
# 3        Clouds  Clouds
# 4        Clouds  Clouds
# 5        Clouds  Clouds
# 6        Clouds  Clouds
# 7         Clear   Clear
# 8        Clouds  Clouds
# 9        Clouds  Clouds
# 10       Clouds  Clouds
# 11       Clouds  Clouds
# 12       Clouds  Clouds
# 13       Clouds  Clouds
# 14         Rain  Clouds
# 15        Clear   Clear
# 16       Clouds  Clouds
# 17        Clear   Clear
# 18       Clouds  Clouds
# 19       Clouds  Clouds
# 20       Clouds  Clouds
# 21       Clouds  Clouds
# 22       Clouds  Clouds
# 23       Clouds    Rain
# 24       Clouds  Clouds
# 25       Clouds  Clouds
# 26       Clouds  Clouds
# 27       Clouds  Clouds
# 28        Clear   Clear
# 29       Clouds  Clouds
# ...         ...     ...
# 4331     Clouds    Rain
# 4332      Clear   Clear
# 4333      Clear   Clear
# 4334     Clouds  Clouds
# 4335     Clouds  Clouds
# 4336     Clouds  Clouds
# 4337     Clouds  Clouds
# 4338     Clouds  Clouds
# 4339      Clear   Clear
# 4340     Clouds  Clouds
# 4341     Clouds    Rain
# 4342     Clouds    Rain
# 4343      Clear   Clear
# 4344      Clear   Clear
# 4345     Clouds  Clouds
# 4346     Clouds  Clouds
# 4347     Clouds  Clouds
# 4348      Clear   Clear
# 4349     Clouds  Clouds
# 4350     Clouds    Rain
# 4351     Clouds  Clouds
# 4352     Clouds    Rain
# 4353     Clouds  Clouds
# 4354       Rain  Clouds
# 4355     Clouds    Rain
# 4356       Rain  Clouds
# 4357       Rain    Rain
# 4358       Rain  Clouds
# 4359     Clouds  Clouds
# 4360     Clouds    Rain
#
# [4361 rows x 2 columns]
